# %%
import matplotlib.pyplot as plt  
import seaborn as sns
import numpy as np
import pandas as pd

# %%
sns.set(style="white", palette="muted", color_codes=True)

# %%
data2 = [2.026923076923077, 1.4, 0.8, 1.1, 1.4, 2.9, 1.5, 2.5, 3.4, 2.0, 2.5, 1.1, 1.6, 1.3, 1.6, 2.8, 2.4, 2.6, 1.9, 2.1, 2.3, 2.4, 1.5, 2.2, 3.0, 2.9, 1.6, 2.0, 4.8, 1.7, 2.9, 2.3, 1.7, 2.5, 4.1, 1.3, 2.2, 2.9, 3.5, 2.9, 1.8, 1.6, 2.9, 3.5, 1.5, 1.5, 1.1, 2.5, 3.4, 3.3, 2.6, 2.2, 2.3, 2.5, 1.4, 1.2, 2.5, 2.8, 2.8, 2.7, 2.6, 2.9, 3.2, 2.6, 1.5, 1.9, 3.8, 1.4, 1.7, 3.4, 3.0, 2.9, 3.9, 1.7, 1.6, 3.2, 2.5, 4.5, 1.9, 0.6, 2.4, 2.4, 1.0, 3.1, 3.5, 3.1]

# %%
KILL = [4.852941176470588, 3.9, 3.0, 5.3, 3.9, 3.1, 4.1, 4.6, 4.3, 1.3, 4.2, 4.8, 7.0, 3.5, 4.4, 3.9, 3.8, 8.0, 3.5, 4.2, 4.5, 3.3, 5.9, 4.2, 4.5, 8.0, 3.0, 5.4, 5.5, 6.3, 3.4, 5.0, 5.9, 5.7, 4.2, 4.8, 3.4, 7.2, 3.8, 4.4, 4.6, 6.1, 5.8, 3.2, 7.5, 7.5, 6.0, 7.8, 3.4, 6.4, 5.0, 6.1, 6.1, 5.4, 6.6, 6.6, 5.7, 5.7, 5.2, 5.0, 3.0, 7.3, 4.4, 5.6, 6.1, 5.2, 3.5, 7.6, 5.6, 3.6, 4.0, 5.8, 2.9, 2.7, 2.8, 6.1, 4.4, 4.2, 5.3, 5.1, 5.1, 7.1, 3.8, 8.1, 6.2]
SCORE = [294.02941176470586, 256.6, 245.7, 295.8, 230.0, 221.5, 264.0, 252.5, 272.4, 183.9, 265.8, 292.0, 384.3, 255.9, 258.9, 241.4, 245.9, 370.7, 244.1, 254.8, 287.9, 254.2, 349.8, 266.4, 289.5, 407.2, 229.2, 315.4, 293.0, 310.6, 239.8, 248.6, 269.5, 300.2, 290.7, 297.4, 260.4, 328.4, 299.3, 272.0, 249.2, 309.6, 323.6, 212.1, 385.8, 384.7, 281.8, 363.7, 250.5, 323.2, 272.0, 300.1, 321.0, 296.8, 330.3, 313.4, 359.1, 296.4, 275.5, 308.4, 227.2, 389.1, 253.0, 306.8]
AMMO = [20.370588235294118, 22.2, 25.0, 19.0, 32.8, 25.6, 23.5, 20.8, 19.3, 30.3, 24.0, 19.3, 16.3, 23.9, 26.4, 33.3, 24.3, 16.3, 30.6, 28.7, 21.8, 22.1, 16.2, 21.1, 22.9, 14.5, 31.2, 19.6, 21.0, 22.3, 28.9, 28.2, 28.2, 22.4, 19.8, 20.4, 19.2, 27.1, 19.7, 21.1, 24.3, 18.1, 20.5, 33.3, 17.6, 13.6, 30.4, 15.4, 33.4, 22.9, 24.1, 22.6, 21.7, 19.3, 26.1, 17.7, 24.2, 28.8, 24.6, 20.6, 29.2, 24.9, 26.5, 22.4]
TIME = [i*10 for i in range(len(KILL))] 
df1 = list(zip(KILL,SCORE, AMMO, TIME))
pd_df1 = pd.DataFrame(data = df1, columns=['KILL', 'AMMO', 'SCORE', 'TIME'])

# %%
g = sns.lmplot(x="TIME", y="KILL", data=pd_df1)
# plt.plot(KILL)
plt.show()
plt.plot(SCORE)
plt.show()

# %%
plt.plot(data2)
plt.show()

# %%
sns.set(style="darkgrid")

# Load the long-form example gammas dataset
gammas = sns.load_dataset("gammas")
print(gammas)
# Plot the response with standard error
sns.tsplot(data=gammas, time="timepoint", unit="subject",
           condition="ROI", value="BOLD signal")

plt.show()
# Out:
#       timepoint  ROI  subject  BOLD signal
# 0           0.0  IPS        0     0.513433
# 1           0.0  IPS        1    -0.414368
# 2           0.0  IPS        2     0.214695
# 3           0.0  IPS        3     0.814809
# 4           0.0  IPS        4    -0.894992
# 5           0.0  IPS        5    -0.073709
# 6           0.0  IPS        6     3.542734
# 7           0.0  IPS        7     0.080169
# 8           0.0  IPS        8     1.547083
# 9           0.0  IPS        9     2.827153
# 10          0.0  IPS       10     2.611358
# 11          0.0  IPS       11    -0.313132
# 12          0.0  IPS       12     3.773421
# 13          0.0  IPS       13     4.829915
# 14          0.0  IPS       14     2.891340
# 15          0.0  IPS       15    -0.736698
# 16          0.0  IPS       16     3.316986
# 17          0.0  IPS       17     3.771426
# 18          0.0  IPS       18     1.308109
# 19          0.0  IPS       19    -0.905172
# 20          0.0   AG        0     1.048369
# ...
