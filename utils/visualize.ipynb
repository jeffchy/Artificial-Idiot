# %%
import matplotlib.pyplot as plt  
import seaborn as sns
import numpy as np
import pandas as pd

# %%
sns.set(style="white", palette="muted", color_codes=True)

# %%
data2 = [2.026923076923077, 1.4, 0.8, 1.1, 1.4, 2.9, 1.5, 2.5, 3.4, 2.0, 2.5, 1.1, 1.6, 1.3, 1.6, 2.8, 2.4, 2.6, 1.9, 2.1, 2.3, 2.4, 1.5, 2.2, 3.0, 2.9, 1.6, 2.0, 4.8, 1.7, 2.9, 2.3, 1.7, 2.5, 4.1, 1.3, 2.2, 2.9, 3.5, 2.9, 1.8, 1.6, 2.9, 3.5, 1.5, 1.5, 1.1, 2.5, 3.4, 3.3, 2.6, 2.2, 2.3, 2.5, 1.4, 1.2, 2.5, 2.8, 2.8, 2.7, 2.6, 2.9, 3.2, 2.6, 1.5, 1.9, 3.8, 1.4, 1.7, 3.4, 3.0, 2.9, 3.9, 1.7, 1.6, 3.2, 2.5, 4.5, 1.9, 0.6, 2.4, 2.4, 1.0, 3.1, 3.5, 3.1]

# %%
KILL = [2.9, 1.5, 2.2, 2.4, 1.4, 1.7, 3.1, 1.5, 1.5, 1.7, 1.5, 1.7, 1.9, 3.8, 1.9, 2.2, 1.7, 1.5, 2.2, 2.5, 2.6, 2.4, 1.9, 1.4, 2.7, 3.8, 2.4, 3.0, 1.0, 2.8, 1.7, 3.7, 2.6, 2.5, 2.4, 2.4, 2.4, 2.6, 2.2, 2.5, 3.2, 2.7, 2.0, 4.0, 2.9, 3.5, 5.0, 2.6, 3.0, 2.6, 2.6, 4.0, 2.8, 3.0, 5.4, 2.6, 3.7, 3.4, 3.3, 5.6, 3.5, 4.9, 5.7, 2.7, 2.3, 2.9, 3.2, 3.4, 3.0, 3.9, 3.7, 5.0, 2.4, 4.5, 5.4, 3.7, 4.9, 3.9, 4.3, 3.9, 3.9, 4.0, 6.5, 2.8, 1.4, 3.5, 3.3, 5.4, 5.5, 4.3, 6.0, 4.6, 4.6, 3.6, 4.9, 4.4, 2.7, 4.2, 5.3, 4.0, 3.3, 3.1, 3.7, 3.2, 4.8, 5.7, 5.1, 4.5, 1.9, 2.8, 4.3, 4.2, 4.4, 3.2, 3.6, 5.6, 4.3, 5.0, 4.0, 4.5, 4.3, 4.1, 4.7, 4.5, 3.6, 5.5, 3.5, 4.5, 5.3, 4.0, 6.6, 4.0]
TIME = [i*10 for i in range(len(KILL))] 
df1 = list(zip(KILL, TIME))
pd_df1 = pd.DataFrame(data = df1, columns=['KILL','TIME'])

# %%
# g = sns.lmplot(x="TIME", y="KILL", data=pd_df1,order=1)
plt.plot(KILL)
plt.show()
plt.plot(SCORE)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a42de162c8b8> in <module>()
#       2 plt.plot(KILL)
#       3 plt.show()
# ----> 4 plt.plot(SCORE)
#       5 plt.show()
#
# NameError: name 'SCORE' is not defined

# %%
plt.plot(data2)
plt.show()

# %%
sns.set(style="darkgrid")

# Load the long-form example gammas dataset
gammas = sns.load_dataset("gammas")
print(gammas)
# Plot the response with standard error
sns.tsplot(data=gammas, time="timepoint", unit="subject",
           condition="ROI", value="BOLD signal")

plt.show()
# Out:
#       timepoint  ROI  subject  BOLD signal
# 0           0.0  IPS        0     0.513433
# 1           0.0  IPS        1    -0.414368
# 2           0.0  IPS        2     0.214695
# 3           0.0  IPS        3     0.814809
# 4           0.0  IPS        4    -0.894992
# 5           0.0  IPS        5    -0.073709
# 6           0.0  IPS        6     3.542734
# 7           0.0  IPS        7     0.080169
# 8           0.0  IPS        8     1.547083
# 9           0.0  IPS        9     2.827153
# 10          0.0  IPS       10     2.611358
# 11          0.0  IPS       11    -0.313132
# 12          0.0  IPS       12     3.773421
# 13          0.0  IPS       13     4.829915
# 14          0.0  IPS       14     2.891340
# 15          0.0  IPS       15    -0.736698
# 16          0.0  IPS       16     3.316986
# 17          0.0  IPS       17     3.771426
# 18          0.0  IPS       18     1.308109
# 19          0.0  IPS       19    -0.905172
# 20          0.0   AG        0     1.048369
# ...
