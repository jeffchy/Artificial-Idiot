# %%
import matplotlib.pyplot as plt  
import seaborn as sns
import numpy as np

# %%
sns.set(style="white", palette="muted", color_codes=True)

# %%
data2 = [2.026923076923077, 1.4, 0.8, 1.1, 1.4, 2.9, 1.5, 2.5, 3.4, 2.0, 2.5, 1.1, 1.6, 1.3, 1.6, 2.8, 2.4, 2.6, 1.9]

# %%
data1 = [4.852941176470588, 3.9, 3.0, 5.3, 3.9, 3.1, 4.1, 4.6, 4.3, 1.3, 4.2, 4.8, 7.0, 3.5, 4.4, 3.9, 3.8, 8.0, 3.5, 4.2, 4.5, 3.3, 5.9, 4.2, 4.5, 8.0, 3.0, 5.4, 5.5, 6.3]

# %%
plt.plot(data1)
plt.show()

# %%
plt.plot(data2)
plt.show()
