# %%
import matplotlib.pyplot as plt  
import seaborn as sns
import numpy as np
import pandas as pd
import glob

# %%
fname = 'data/output3'

# %%
f = open(fname,'r')

# %%
s = f.read()
l = s.split('\n')
l = [i for i in l if i != '' and i[0] == 'T']
l = l[1:]
l = [i.split() for i in l]
print(l)
# Out:
# [['TIME', '49', '/', 'GAME', '1', '/', 'STATE', 'observe', '/', 'EPSILON', '1.0', '/', 'ACTION', '4', '/', 'REWARD', '0.6', '/', 'Q_MAX', '0.000000e+00', '/', 'LIFE', '48', '/', 'LOSS', '0'], ['TIME', '264', '/', 'GAME', '2', '/', 'STATE', 'observe', '/', 'EPSILON', '1.0', '/', 'ACTION', '6', '/', 'REWARD', '1.5', '/', 'Q_MAX', '0.000000e+00', '/', 'LIFE', '214', '/', 'LOSS', '0'], ['TIME', '425', '/', 'GAME', '3', '/', 'STATE', 'observe', '/', 'EPSILON', '1.0', '/', 'ACTION', '4', '/', 'REWARD', '1.5', '/', 'Q_MAX', '0.000000e+00', '/', 'LIFE', '214', '/', 'LOSS', '0'], ['TIME', '617', '/', 'GAME', '4', '/', 'STATE', 'observe', '/', 'EPSILON', '1.0', '/', 'ACTION', '0', '/', 'REWARD', '1.5', '/', 'Q_MAX', '0.000000e+00', '/', 'LIFE', '214', '/', 'LOSS', '0'], ['TIME', '848', '/', 'GAME', '5', '/', 'STATE', 'observe', '/', 'EPSILON', '1.0', '/', 'ACTION', '2', '/', 'REWARD', '0.6', '/', 'Q_MAX', '0.000000e+00', '/', 'LIFE', '230', '/', 'LOSS', '0'], ['TIME', '982', '/', 'GAME', '6', 
# ...

# %%
TIME = [i[1] for i in l if i[7] == 'train']
LIFE = [i[-4] for i in l if i[7] == 'train']

# %%
f.close()
